# %% [markdown]
# Page 1

# %%
[
    "gumppic 0 0 39923",
    "xmfhtmlgump 60 9 147 22 1011296 0 0",
    "htmlgump 110 9 97 22 0 0 0",
    "xmfhtmlgump 264 9 144 18 1011299 0 0",
    "button 248 14 2103 2103 1 0 1",

    "button 196 55 2437 2438 1 0 3000",
    "tooltip 1042971 @Move down@",
    "gumppic 15 55 2224",
    "tooltip 1042971 @default@",
    "button 36 55 2103 2104 1 0 100",
    "croppedtext 52 50 134 18 331 1",
    "tooltip 1042971 @Deutschland@",

    "button 186 75 2435 2436 1 0 2001",
    "tooltip 1042971 @Move up@",
    "button 196 75 2437 2438 1 0 3001",
    "tooltip 1042971 @Move down@",
    "button 36 75 2103 2104 1 0 101",
    "croppedtext 52 70 134 18 10 2",
    "tooltip 1042971 @New Haven Bank@",

    "button 186 95 2435 2436 1 0 2002",
    "tooltip 1042971 @Move up@",
    "button 36 95 2103 2104 1 0 102",
    "croppedtext 52 90 134 18 1154 3",
    "tooltip 1042971 @UOAlive Community Center and Reporter Headquarters@",

    "button 36 115 2103 2104 1 0 103",
    "croppedtext 52 110 134 18 0 4",
    "tooltip 1042971 @Empty@",

    "button 36 135 2103 2104 1 0 104",
    "croppedtext 52 130 134 18 0 4",
    "tooltip 1042971 @Empty@",

    "button 36 155 2103 2104 1 0 105",
    "croppedtext 52 150 134 18 0 4",
    "tooltip 1042971 @Empty@",

    "button 36 175 2103 2104 1 0 106",
    "croppedtext 52 170 134 18 0 4",
    "tooltip 1042971 @Empty@",

    "button 36 195 2103 2104 1 0 107",
    "croppedtext 52 190 134 18 0 4",
    "tooltip 1042971 @Empty@",

    "button 241 55 2103 2104 1 0 108",
    "croppedtext 257 50 134 18 0 4",
    "tooltip 1042971 @Empty@",

    "button 241 75 2103 2104 1 0 109",
    "croppedtext 257 70 134 18 0 4",
    "tooltip 1042971 @Empty@",

    "button 241 95 2103 2104 1 0 110",
    "croppedtext 257 90 134 18 0 4",
    "tooltip 1042971 @Empty@",

    "button 241 115 2103 2104 1 0 111",
    "croppedtext 257 110 134 18 0 4",
    "tooltip 1042971 @Empty@",

    "button 241 135 2103 2104 1 0 112",
    "croppedtext 257 130 134 18 0 4",
    "tooltip 1042971 @Empty@",

    "button 241 155 2103 2104 1 0 113",
    "croppedtext 257 150 134 18 0 4",
    "tooltip 1042971 @Empty@",

    "button 241 175 2103 2104 1 0 114",
    "croppedtext 257 170 134 18 0 4",
    "tooltip 1042971 @Empty@",

    "button 241 195 2103 2104 1 0 115",
    "croppedtext 257 190 134 18 0 4",
    "tooltip 1042971 @Empty@",
    
    "htmlgump 25 254 182 18 5 0 0",
    "xmfhtmlgump 62 290 144 18 1011300 0 0",
    "button 46 295 2103 2103 1 0 2",
    "xmfhtmlgump 62 310 144 18 1011298 0 0",
    "button 46 315 2103 2103 1 0 3",
    "htmlgump 62 330 144 18 6 0 0",
    "button 46 335 2103 2103 1 0 8",
    "htmlgump 25 348 182 18 7 0 0",
    "xmfhtmlgump 280 284 128 18 1077595 0 0",
    "button 264 289 2103 2103 1 0 4",
    "xmfhtmlgump 280 302 128 18 1015214 0 0",
    "button 264 307 2103 2103 1 0 6",
    "xmfhtmlgump 280 320 128 18 1060502 0 0",
    "button 264 325 2103 2103 1 0 7",
    "button 374 3 2206 2206 1 0 1150",
]

# %%
[
    "0 / 100",
    "Blighted Grove",
    "Covetous",
    "Covetous 2",
    "Covetous 3",
    "Covetous 4",
    "Deceit",
    "Deceit 2",
    "Deceit 3/4 Stairs",
    "Despise",
    "Destard",
    "Destard 2",
    "Destard 3",
    "Hythloth",
    "Hythloth 2",
    "Hythloth 3",
    "Hythloth 4",
    "<center>122?? 52'N, 50?? 33'E</center>",
    "Replace",
    "<center>Wrong</center>",
    "",
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
]
[
    "0 / 100",
    "Blighted Grove",
    "Covetous",
    "Covetous 2",
    "Covetous 3",
    "Covetous 4",
    "Deceit",
    "Deceit 2",
    "Deceit 3/4 Stairs",
    "Despise",
    "Destard",
    "Destard 2",
    "Destard 3",
    "Hythloth",
    "Hythloth 2",
    "Hythloth 3",
    "Hythloth 4",
    "<center>122?? 52'N, 50?? 33'E</center>",
    "Replace",
    "<center>Wrong</center>",
    "Orc Cave 1",
    "Orc Cave 2",
    "Orc Cave 3",
    "Painted Caves",
    "Prism of Light",
    "Sanctuary",
    "Shame",
    "Shame 2",
    "Shame 3",
    "Shame 4",
    "Wind",
    "Wrong",
    "Ice Dungeon",
    "Ice Dungeon 2",
    "Fire Dungeon",
    "Fire Dungeon 2",
    "",
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
]
[
    "0 / 100",
    "Blighted Grove",
    "Covetous",
    "Covetous 2",
    "Covetous 3",
    "Covetous 4",
    "Deceit",
    "Deceit 2",
    "Deceit 3/4 Stairs",
    "Despise",
    "Destard",
    "Destard 2",
    "Destard 3",
    "Hythloth",
    "Hythloth 2",
    "Hythloth 3",
    "Hythloth 4",
    "<center>122?? 52'N, 50?? 33'E</center>",
    "Replace",
    "<center>Wrong</center>",
    "Orc Cave 1",
    "Orc Cave 2",
    "Orc Cave 3",
    "Painted Caves",
    "Prism of Light",
    "Sanctuary",
    "Shame",
    "Shame 2",
    "Shame 3",
    "Shame 4",
    "Wind",
    "Wrong",
    "Ice Dungeon",
    "Ice Dungeon 2",
    "Fire Dungeon",
    "Fire Dungeon 2",
    "Palace of Paroxymus",
    "Underworld",
    "Black Solen Hive",
    "Red Solen Hive",
    "Empty",
    "",
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
]

# %% [markdown]
# Page 2

# %%
[
    "gumppic 0 0 39923",
    "xmfhtmlgump 60 9 147 22 1011296 0 0",
    "htmlgump 110 9 97 22 0 0 0",
    "xmfhtmlgump 264 9 144 18 1011299 0 0",
    "button 248 14 2103 2103 1 0 1",
    "button 36 55 2103 2104 1 0 116",
    "croppedtext 52 50 154 18 10 20",
    "tooltip 1042971 @Orc Cave 1@",
    "button 36 75 2103 2104 1 0 117",
    "croppedtext 52 70 154 18 10 21",
    "tooltip 1042971 @Orc Cave 2@",
    "button 36 95 2103 2104 1 0 118",
    "croppedtext 52 90 154 18 10 22",
    "tooltip 1042971 @Orc Cave 3@",
    "button 36 115 2103 2104 1 0 119",
    "croppedtext 52 110 154 18 10 23",
    "tooltip 1042971 @Painted Caves@",
    "button 36 135 2103 2104 1 0 120",
    "croppedtext 52 130 154 18 10 24",
    "tooltip 1042971 @Prism of Light@",
    "button 36 155 2103 2104 1 0 121",
    "croppedtext 52 150 154 18 10 25",
    "tooltip 1042971 @Sanctuary@",
    "button 36 175 2103 2104 1 0 122",
    "croppedtext 52 170 154 18 10 26",
    "tooltip 1042971 @Shame@",
    "button 36 195 2103 2104 1 0 123",
    "croppedtext 52 190 154 18 10 27",
    "tooltip 1042971 @Shame 2@",
    "button 241 55 2103 2104 1 0 124",
    "croppedtext 257 50 154 18 10 28",
    "tooltip 1042971 @Shame 3@",
    "button 241 75 2103 2104 1 0 125",
    "croppedtext 257 70 154 18 10 29",
    "tooltip 1042971 @Shame 4@",
    "button 241 95 2103 2104 1 0 126",
    "croppedtext 257 90 154 18 10 30",
    "tooltip 1042971 @Wind@",
    "button 241 115 2103 2104 1 0 127",
    "croppedtext 257 110 154 18 331 31",
    "tooltip 1042971 @Wrong@",
    "button 241 135 2103 2104 1 0 128",
    "croppedtext 257 130 154 18 10 32",
    "tooltip 1042971 @Ice Dungeon@",
    "button 241 155 2103 2104 1 0 129",
    "croppedtext 257 150 154 18 10 33",
    "tooltip 1042971 @Ice Dungeon 2@",
    "button 241 175 2103 2104 1 0 130",
    "croppedtext 257 170 154 18 10 34",
    "tooltip 1042971 @Fire Dungeon@",
    "button 241 195 2103 2104 1 0 131",
    "croppedtext 257 190 154 18 10 35",
    "tooltip 1042971 @Fire Dungeon 2@",
    "htmlgump 25 254 182 18 17 0 0",
    "xmfhtmlgump 62 290 144 18 1011300 0 0",
    "button 46 295 2103 2103 1 0 2",
    "xmfhtmlgump 62 310 144 18 1011298 0 0",
    "button 46 315 2103 2103 1 0 3",
    "htmlgump 62 330 144 18 18 0 0",
    "button 46 335 2103 2103 1 0 8",
    "htmlgump 25 348 182 18 19 0 0",
    "xmfhtmlgump 280 284 128 18 1077595 0 0",
    "button 264 289 2103 2103 1 0 4",
    "xmfhtmlgump 280 302 128 18 1015214 0 0",
    "button 264 307 2103 2103 1 0 6",
    "xmfhtmlgump 280 320 128 18 1060502 0 0",
    "button 264 325 2103 2103 1 0 7",
    "button 374 3 2206 2206 1 0 1150",
    "button 23 5 2205 2205 1 0 1151",
]
# Out:
# ['gumppic 0 0 39923', 'xmfhtmlgump 60 9 147 22 1011296 0 0', 'htmlgump 110 9 97 22 0 0 0', 'xmfhtmlgump 264 9 144 18 1011299 0 0', 'button 248 14 2103 2103 1 0 1', 'button 36 55 2103 2104 1 0 116', 'croppedtext 52 50 154 18 10 20', 'tooltip 1042971 @Orc Cave 1@', 'button 36 75 2103 2104 1 0 117', 'croppedtext 52 70 154 18 10 21', 'tooltip 1042971 @Orc Cave 2@', 'button 36 95 2103 2104 1 0 118', 'croppedtext 52 90 154 18 10 22', 'tooltip 1042971 @Orc Cave 3@', 'button 36 115 2103 2104 1 0 119', 'croppedtext 52 110 154 18 10 23', 'tooltip 1042971 @Painted Caves@', 'button 36 135 2103 2104 1 0 120', 'croppedtext 52 130 154 18 10 24', 'tooltip 1042971 @Prism of Light@', 'button 36 155 2103 2104 1 0 121', 'croppedtext 52 150 154 18 10 25', 'tooltip 1042971 @Sanctuary@', 'button 36 175 2103 2104 1 0 122', 'croppedtext 52 170 154 18 10 26', 'tooltip 1042971 @Shame@', 'button 36 195 2103 2104 1 0 123', 'croppedtext 52 190 154 18 10 27', 'tooltip 1042971 @Shame 2@', 'button 241 55 2103 2104 1
# ...

# %% [markdown]
# Example of `gd.stringList`

# %% [markdown]
# ```
# 0 / 100
# BLIGHTED GROVE
# Jamal the Fisherman
# Ioseph the Exporter
# BEDLAM
# Mistress of Admissions
# Gorrow Mayor of Luna
# Unicorn and Ki-Rin
# Ilshenar-Sprituality Go N
# EXPLORING THE DEEP
# Hepler Paulson
# Tinker's Residence
# Cousteau Perron
# Josef Skimmons
# Orc Mines
# Orc Mines (alternate)
# Madeline Harte
# <center>165° 3'N, 22° 51'W</center>
# Replace
# <center>↓ ABYSS ↓</center>
# ↓ BMV ARARAT DOCK ↓
# Destard Entrance
# The Seedy Cobbler
# Bandit Mercutio
# BMV Ararat Dock
# ↓ ABYSS ↓
# Book of Circles
# Shrine of Singularity
# Empty
# <center>Nowhere</center>
# <center>Empty</center>
# <center>22° 8'N, 52° 18'E</center>
# <center>BEDLAM</center>
#
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ```
