# %% [markdown]
# ```
# gumpData:
# List[str]()
#
# gumpDefinition:
#
#
# gumpLayout:
# { gumppic 0 0 1473 }
# { xmfhtmlgumpcolor 10 10 580 20 1153552 0 0 17400 }
# { xmfhtmlgumpcolor 35 40 35 20 1153554 0 0 17183 }
# { xmfhtmlgumpcolor 70 40 90 20 1153555 0 0 17183 }
# { button 140 45 2435 2436 1 0 4 }
# { tooltip 1042971 @Sort ascending@ }
# { button 152 45 2437 2438 1 0 5 }
# { tooltip 1042971 @Sort descending@ }
# { xmfhtmlgumpcolor 198 40 140 20 1153557 0 0 17183 }
# { button 335 45 2435 2436 1 0 24 }
# { tooltip 1042971 @Sort ascending@ }
# { button 347 45 2437 2438 1 0 25 }
# { tooltip 1042971 @Sort descending@ }
# { xmfhtmlgumpcolor 365 40 90 20 1153556 0 0 17183 }
# { button 440 45 2435 2436 1 0 44 }
# { tooltip 1042971 @Sort ascending@ }
# { button 452 45 2437 2438 1 0 45 }
# { tooltip 1042971 @Sort descending@ }
# { xmfhtmlgumpcolor 473 40 110 20 1153558 0 0 17183 }
# { button 560 45 2435 2436 1 0 64 }
# { tooltip 1042971 @Sort ascending@ }
# { button 572 45 2437 2438 1 0 65 }
# { tooltip 1042971 @Sort descending@ }
# { xmfhtmltok 35 430 280 20 0 0 17183 1153560 @219@500@ }  # Number of maps
# { xmfhtmltok 35 450 280 20 0 0 17183 1153561 @1@22@ }  # Page
# { xmfhtmlgumpcolor 390 430 100 20 1153553 0 0 32752 }
# { button 350 430 4011 4013 1 0 62 }
# { xmfhtmlgumpcolor 390 450 100 20 1153562 0 0 32752 }
# { button 350 450 4014 4016 1 0 22 }  # Left
# { button 500 450 4005 4007 1 0 42 }  # Right
# { button 330 453 5603 5607 1 0 222 }
# { button 534 453 5601 5605 1 0 242 }
# { button 45 77 1209 1210 1 0 3 }
# { xmfhtmlgumpcolor 78 73 110 20 1060643 0 0 32752 }  # Facet (Malas)
# { xmfhtmlgumpcolor 410 73 110 20 1159000 0 0 32752 } # Type (Artisan's)
# { xmfhtmlgumpcolor 373 73 110 20 1158994 0 0 32752 }  # Level (1158994 : Cache)
# { xmfhtmltok 198 73 140 20 0 0 32752 1060847 @1518, 1291@ }  # coordinates
# { xmfhtmlgumpcolor 473 73 150 20 1153581 0 0 32752 }  # Decoding Status (1153581: Decoded)
# { button 45 112 1209 1210 1 0 23 }
# { xmfhtmlgumpcolor 78 108 110 20 1060643 0 0 32752 }
# { xmfhtmlgumpcolor 410 108 110 20 1159000 0 0 32752 }
# { xmfhtmlgumpcolor 373 108 110 20 1158994 0 0 32752 }
# { xmfhtmltok 198 108 140 20 0 0 32752 1060847 @1531, 1454@ }
# { xmfhtmlgumpcolor 473 108 150 20 1153581 0 0 32752 }
# { button 45 147 1209 1210 1 0 43 }
# { xmfhtmlgumpcolor 78 143 110 20 1060643 0 0 32752 }
# { xmfhtmlgumpcolor 410 143 110 20 1159000 0 0 32752 }
# { xmfhtmlgumpcolor 373 143 110 20 1158994 0 0 32752 }
# { xmfhtmltok 198 143 140 20 0 0 32752 1060847 @1663, 629@ }
# { xmfhtmlgumpcolor 473 143 150 20 1153581 0 0 32752 }
# { button 45 182 1209 1210 1 0 63 }
# { xmfhtmlgumpcolor 78 178 110 20 1060643 0 0 32752 }
# { xmfhtmlgumpcolor 410 178 110 20 1159000 0 0 32752 }
# { xmfhtmlgumpcolor 373 178 110 20 1158994 0 0 32752 }
# { xmfhtmltok 198 178 140 20 0 0 32752 1060847 @1672, 658@ }
# { xmfhtmlgumpcolor 473 178 150 20 1153581 0 0 32752 }
# { button 45 217 1209 1210 1 0 83 }
# { xmfhtmlgumpcolor 78 213 110 20 1060643 0 0 32752 }
# { xmfhtmlgumpcolor 410 213 110 20 1159000 0 0 32752 }
# { xmfhtmlgumpcolor 373 213 110 20 1158994 0 0 32752 }
# { xmfhtmltok 198 213 140 20 0 0 32752 1060847 @2438, 1179@ }
# { xmfhtmlgumpcolor 473 213 150 20 1153581 0 0 32752 }
# { button 45 252 1209 1210 1 0 103 }
# { xmfhtmlgumpcolor 78 248 110 20 1112178 0 0 32752 }  # Ter Mur
# { xmfhtmlgumpcolor 410 248 110 20 1159000 0 0 32752 }
# { xmfhtmlgumpcolor 373 248 110 20 1158994 0 0 32752 }
# { xmfhtmltok 198 248 140 20 0 0 32752 1060847 @628, 1958@ }
# { xmfhtmlgumpcolor 473 248 150 20 1153581 0 0 32752 }
# { button 45 287 1209 1210 1 0 123 }
# { xmfhtmlgumpcolor 78 283 110 20 1063258 0 0 32752 }  # Tokuno Islands
# { xmfhtmlgumpcolor 410 283 110 20 1159000 0 0 32752 }
# { xmfhtmlgumpcolor 373 283 110 20 1158994 0 0 32752 }
# { xmfhtmltok 198 283 140 20 0 0 32752 1060847 @389, 990@ }
# { xmfhtmlgumpcolor 473 283 150 20 1153581 0 0 32752 }
# { button 45 322 1209 1210 1 0 143 }
# { xmfhtmlgumpcolor 78 318 110 20 1063258 0 0 32752 }
# { xmfhtmlgumpcolor 410 318 110 20 1159000 0 0 32752 }
# { xmfhtmlgumpcolor 373 318 110 20 1158994 0 0 32752 }
# { xmfhtmltok 198 318 140 20 0 0 32752 1060847 @504, 89@ }
# { xmfhtmlgumpcolor 473 318 150 20 1153581 0 0 32752 }
# { button 45 357 1209 1210 1 0 163 }
# { xmfhtmlgumpcolor 78 353 110 20 1012000 0 0 32752 }  # Trammel
# { xmfhtmlgumpcolor 410 353 110 20 1159000 0 0 32752 }
# { xmfhtmlgumpcolor 373 353 110 20 1158994 0 0 32752 }
# { xmfhtmltok 198 353 140 20 0 0 32752 1060847 @3234, 702@ }
# { xmfhtmlgumpcolor 473 353 150 20 1153581 0 0 32752 }
# { button 45 392 1209 1210 1 0 183 }
# { xmfhtmlgumpcolor 78 388 110 20 1012001 0 0 32752 }  # Felucca
# { xmfhtmlgumpcolor 410 388 110 20 1158998 0 0 32752 }
# { xmfhtmlgumpcolor 373 388 110 20 1158994 0 0 32752 }
# { xmfhtmltok 198 388 140 20 0 0 32752 1060847 @691, 1688@ }
# { xmfhtmlgumpcolor 473 388 150 20 1153581 0 0 32752 }
#
# gumpStrings:
# List[str]()
#
# gumpText:
# List[str](['<DIV ALIGN="CENTER">Davies\' Locker</DIV>', '<DIV ALIGN="CENTER">Get</DIV>', '<DIV ALIGN="CENTER">Facet</DIV>', '~1_NOTHING~', '~1_NOTHING~', '<DIV ALIGN="CENTER">Coords</DIV>', '~1_NOTHING~', '~1_NOTHING~', '<DIV ALIGN="CENTER">Level</DIV>', '~1_NOTHING~', '~1_NOTHING~', '<DIV ALIGN="CENTER">Status</DIV>', '~1_NOTHING~', '~1_NOTHING~', 'Maps: ~1_NUM~ of ~2_MAX~', 'Page ~1_CUR~ of ~2_MAX~', '<DIV ALIGN="CENTER">ADD MAPS</DIV>', '<DIV ALIGN="CENTER">PAGE</DIV>', 'Malas', '~1_val~ ~2_val~', 'Decoded', 'Malas', '~1_val~ ~2_val~', 'Decoded', 'Malas', '~1_val~ ~2_val~', 'Decoded', 'Malas', '~1_val~ ~2_val~', 'Decoded', 'Malas', '~1_val~ ~2_val~', 'Decoded', 'Ter Mur', '~1_val~ ~2_val~', 'Decoded', 'Tokuno Islands', '~1_val~ ~2_val~', 'Decoded', 'Tokuno Islands', '~1_val~ ~2_val~', 'Decoded', 'Trammel', '~1_val~ ~2_val~', 'Decoded', 'Felucca', '~1_val~ ~2_val~', 'Decoded'])
# ```

# %% [markdown]
# Facets:
# * 1012001 : Felucca
# * 1012000 : Trammel
# * 1012002 : Ilshenar
# * 1060643 : Malas
# * 1063258 : Tokuno Islands
# * 1112178 : Ter Mur
# * 1156262 : Valley of Eodon (verification needed)
#
# Levels:
# * 1158992 : Stash
# * 1158993 : Supply
# * 1158994 : Cache
# * 1158995 : Hoard
# * 1158996 : Trove
#
# Types:
# * 1158997 : Mage's
# * 1158998 : Assassin's
# * 1158999 : Warrior's
# * 1159000 : Artisan's
# * 1159002 : Ranger's
#
# Decoding Status:
# * 1153580 : Not Decoded
# * 1153581 : Decoded
# * 1153582 : Completed
#
# Coordinates:
# * 1153569 : Unknown
# * 1060847 : ~1_val~ ~2_val~
