# %% [markdown]
# ```
# { page 0 }
# { gumppic 30 30 2172 }
# { page 1 }
#
# 46 + 70 * col
# 41 + 65 * row
#
# { buttontileart 46 41 2184 2184 1 0 100 3535 1158 3 30 }
# { tooltip 1061917 @#1061852	#1023223@ }
# { buttontileart 116 41 2185 2185 1 0 101 3535 1166 3 30 }
# { tooltip 1061917 @#1061854	#1023211@ }
# { buttontileart 186 41 2183 2183 1 0 102 3535 1166 3 30 }
# { tooltip 1113492 @2	#1061854	#1023332@ }
# { buttontileart 256 41 2184 2184 1 0 103 3535 1166 3 30 }
# { tooltip 1061917 @#1061854	#1023206@ }
#
# { buttontileart 46 106 2183 2183 1 0 104 3535 1173 3 30 }
# { tooltip 1113492 @2	#1061853	#1023239@ }
# { buttontileart 116 106 2184 2184 1 0 105 3535 1173 3 30 }
# { tooltip 1113492 @2	#1061853	#1023367@ }
# { buttontileart 186 106 2185 2185 1 0 106 3535 1173 3 30 }
# { tooltip 1061917 @#1061853	#1023238@ }
# { buttontileart 256 106 2184 2184 1 0 107 3535 1158 3 30 }
# { tooltip 1061917 @#1061852	#1023211@ }
#
# { buttontileart 46 171 2183 2183 1 0 108 3535 1166 3 30 }
# { tooltip 1061917 @#1061854	#1023377@ }
# { buttontileart 116 171 2185 2185 1 0 109 3535 1173 3 30 }
# { tooltip 1061917 @#1061853	#1023228@ }
# { buttontileart 186 171 2184 2184 1 0 110 3535 1158 3 30 }
# { tooltip 1061917 @#1061852	#1023332@ }
# { buttontileart 256 171 2184 2184 1 0 111 3535 1166 3 30 }
# { tooltip 1061917 @#1061854	#1023366@ }
#
# { buttontileart 46 236 2183 2183 1 0 112 3535 1158 3 30 }
# { tooltip 1061917 @#1061852	#1023203@ }
# ```

# %% [markdown]
# ```
# gumpData:
# List[str]()
#
# gumpDefinition:
#
#
# gumpLayout:
# { page 0 }
# { gumppic 30 30 2172 }
# { page 1 }
#
# { buttontileart 46 41 2184 2184 1 0 100 3535 0 3 30 }
# { tooltip 1113492 @15	#1063335	#1030460@ }
# { buttontileart 116 41 2184 2184 1 0 101 3535 0 3 30 }
# { tooltip 1113492 @31	#1063335	#1030463@ }
# { buttontileart 186 41 2184 2184 1 0 102 3535 0 3 30 }
# { tooltip 1113492 @5	#1063336	#1030464@ }
# { buttontileart 256 41 2183 2183 1 0 103 3535 0 3 30 }
# { tooltip 1113492 @15	#1063336	#1030461@ }
#
# { buttontileart 46 106 2183 2183 1 0 104 3535 0 3 30 }
# { tooltip 1113492 @10	#1063341	#1030466@ }
# { buttontileart 116 106 2184 2184 1 0 105 3535 0 3 30 }
# { tooltip 1113492 @4	#1063337	#1030465@ }
# { buttontileart 186 106 2184 2184 1 0 106 3535 0 3 30 }
# { tooltip 1113492 @11	#1063337	#1030462@ }
# { buttontileart 256 106 2184 2184 1 0 107 3535 0 3 30 }
# { tooltip 1113492 @7	#1063342	#1030467@ }
#
# { buttontileart 46 171 2185 2185 1 0 108 3535 0 3 30 }
# { tooltip 1113492 @14	#1060813	#1023273@ }
# { buttontileart 116 171 2183 2183 1 0 109 3535 0 3 30 }
# { tooltip 1113492 @7	#1060813	#1026810@ }
# { buttontileart 186 171 2184 2184 1 0 110 3535 0 3 30 }
# { tooltip 1113492 @10	#1060813	#1023204@ }
# { buttontileart 256 171 2183 2183 1 0 111 3535 0 3 30 }
# { tooltip 1113492 @12	#1060813	#1026815@ }
#
# { buttontileart 46 236 2183 2183 1 0 112 3535 0 3 30 }
# { tooltip 1113492 @12	#1060813	#1023265@ }
# { buttontileart 116 236 2183 2183 1 0 113 3535 0 3 30 }
# { tooltip 1113492 @23	#1060813	#1023326@ }
# { buttontileart 186 236 2184 2184 1 0 114 3535 0 3 30 }
# { tooltip 1113492 @45	#1060813	#1023215@ }
# { buttontileart 256 236 2183 2183 1 0 115 3535 0 3 30 }
# { tooltip 1113492 @47	#1060813	#1023272@ }
#
# { buttontileart 46 301 2184 2184 1 0 116 3535 0 3 30 }
# { tooltip 1113492 @15	#1060813	#1023214@ }
# { buttontileart 116 301 2184 2184 1 0 117 3535 0 3 30 }
# { tooltip 1113492 @3	#1060813	#1023365@ }
# { buttontileart 186 301 2183 2183 1 0 118 3535 0 3 30 }
# { tooltip 1113492 @2	#1060813	#1023255@ }
# { buttontileart 256 301 2184 2184 1 0 119 3535 0 3 30 }
# { tooltip 1113715 @13	#1060813	#1029324@ }
#
# { xmfhtmltok 136 373 100 25 0 0 28539 1151850 @@1@2@ }
# { button 276 375 5601 5601 1 0 2 }
#
# gumpStrings:
# List[str]()
#
# gumpText:
# List[str](['~1_amount~ ~2_color~ ~3_type~ seeds', 'common', 'bonsai tree', '~1_amount~ ~2_color~ ~3_type~ seeds', 'common', 'bonsai tree', '~1_amount~ ~2_color~ ~3_type~ seeds', 'uncommon', 'bonsai tree', '~1_amount~ ~2_color~ ~3_type~ seeds', 'uncommon', 'bonsai tree', '~1_amount~ ~2_color~ ~3_type~ seeds', 'exceptional', 'bonsai tree', '~1_amount~ ~2_color~ ~3_type~ seeds', 'rare', 'bonsai tree', '~1_amount~ ~2_color~ ~3_type~ seeds', 'rare', 'bonsai tree', '~1_amount~ ~2_color~ ~3_type~ seeds', 'exotic', 'bonsai tree', '~1_amount~ ~2_color~ ~3_type~ seeds', 'plain', 'spider tree', '~1_amount~ ~2_color~ ~3_type~ seeds', 'plain', 'flax', '~1_amount~ ~2_color~ ~3_type~ seeds', 'plain', 'foxglove flowers', '~1_amount~ ~2_color~ ~3_type~ seeds', 'plain', 'hops', '~1_amount~ ~2_color~ ~3_type~ seeds', 'plain', 'orfluer flowers', '~1_amount~ ~2_color~ ~3_type~ seeds', 'plain', 'cypress tree', '~1_amount~ ~2_color~ ~3_type~ seeds', 'plain', 'hedge', '~1_amount~ ~2_color~ ~3_type~ seeds', 'plain', 'juniper bush', '~1_amount~ ~2_color~ ~3_type~ seeds', 'plain', 'snowdrops', '~1_amount~ ~2_color~ ~3_type~ seeds', 'plain', 'cactus', '~1_amount~ ~2_color~ ~3_type~ seeds', 'plain', 'cattails', '~1_AMOUNT~ sugar cane seeds', 'plain', 'bamboo', '{Page: ~1_val~ / ~2_val~}'])
# ```

# %%
color_map = [
    (0, "plain"),
    (0x0021, "bright red"),
    (0x066D, "red"),
    (0x002B, "bright orange"),
    (0x046F, "orange"),
    (0x0038, "bright yellow"),
    (0x08A5, "yellow"),
    (0x0042, "bright green"),
    (0x059B, "green"),
    (0x0005, "bright blue"),
    (0x053D, "blue"),
    (0x0010, "bright purple"),
    (0x000D, "purple"),
    (0x048E, "rare pink"),
    (0x0495, "rare aqua"),
    (0x0486, "rare magenta"),
    (0x0489, "rare fire red"),
    (0x0481, "white"),
    (0x0455, "black"),
]

print({color[0]: i for i, color in enumerate(color_map)})
# Out:
# {0: 0, 33: 1, 1645: 2, 43: 3, 1135: 4, 56: 5, 2213: 6, 66: 7, 1435: 8, 5: 9, 1341: 10, 16: 11, 13: 12, 1166: 13, 1173: 14, 1158: 15, 1161: 16, 1153: 17, 1109: 18}
